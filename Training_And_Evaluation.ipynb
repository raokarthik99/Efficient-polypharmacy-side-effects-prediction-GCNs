# %% [markdown]
# #**1. Initialization**

# %% [markdown]
# ##1.1. Mounting google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##1.2. Navigating to working directory

# %%
cd '/content/drive/MyDrive/DSML_LAB_PROJECT/Project_Files'
# Out:
# /content/drive/MyDrive/TIP-WorkingCopy/TIP

# %% [markdown]
# ##1.3. Installing packages

# %%
# !pip uninstall -y torch torchvision 
# !pip install torch==1.1.0   torchvision==0.3.0
# !pip install torch-cluster==1.4.2
# !pip install torch-geometric==1.3.0
# !pip install torch-scatter==1.3.1
# !pip install torch-sparse==0.4.0 
# !pip install scikit-learn==0.20.3
# !pip install pytorch-memlab==0.0.3
# Out:
# Uninstalling torch-1.7.0+cu101:
#   Successfully uninstalled torch-1.7.0+cu101
# Uninstalling torchvision-0.8.1+cu101:
#   Successfully uninstalled torchvision-0.8.1+cu101
# ...
#      |████████████████████████████████| 676.9MB 25kB/s
# ...
#      |████████████████████████████████| 2.6MB 62.8MB/s
# ...
#      |████████████████████████████████| 716kB 8.8MB/s
# ...
#   Created wheel for torch-cluster: filename=torch_cluster-1.4.2-cp36-cp36m-linux_x86_64.whl size=14148464 sha256=a89c97d9b0e31e871c7583432f59824cb1b6a6b40feb6fd58dcca0cab2f84c98
#   Stored in directory: /root/.cache/pip/wheels/ee/54/4a/eb079ec61377a93ea07aba9eea53adcae41450111b54de0118
# Successfully built torch-cluster
# ...
#      |████████████████████████████████| 112kB 9.0MB/s
# ...
#      |████████████████████████████████| 235kB 12.9MB/s
# ...
#      |████████████████████████████████| 51kB 6.0MB/s
# ...

# %% [markdown]
# # **2. Training the model variants**

# %% [markdown]
# ##2.1. DistMult: DF

# %%
# %run model/df_distmult.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# cuda
#   0   loss:         auprc:0.4998   auroc:0.5010   ap@50:0.5053
# model training ...
#   1   time:25.06
#   2   time:24.96
#   3   time:25.03
#   4   time:25.03
#   5   time:25.00
#   6   time:25.00
#   7   time:24.94
#   8   time:24.88
#   9   time:24.84
#  10   loss:1.4041   auprc:0.5144   auroc:0.5219   ap@50:0.5198    time:33.3
#  11   time:24.89
#  12   time:24.90
#  13   time:24.98
#  14   time:24.74
#  15   time:24.84
#  16   time:24.90
#  17   time:24.79
#  18   time:24.76
#  19   time:24.95
#  20   loss:1.3757   auprc:0.5536   auroc:0.5729   ap@50:0.5589    time:33.3
#  21   time:24.78
#  22   time:24.92
#  23   time:24.86
#  24   time:24.97
#  25   time:25.07
#  26   time:24.81
#  27   time:24.72
#  28   time:24.67
#  29   time:24.84
#  30   loss:1.3315   auprc:0.6286   auroc:0.6571   ap@50:0.6332    time:33.1
#  31   time:24.77
# ...

# %% [markdown]
# ## 2.2. R-GCN: DDM-DF

# %%
# %run model/ddm_df_rgcn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# cuda
# model training ...
#   0   loss:1.3865   auprc:0.5015   auroc:0.5018   ap@50:0.5023
#   0   loss:1.3865   auprc:0.5016   auroc:0.5003   ap@50:0.5070    time:50.8
#
#   1   loss:1.3863   auprc:0.5031   auroc:0.5037   ap@50:0.5044
#   1   loss:1.3863   auprc:0.5032   auroc:0.5026   ap@50:0.5091    time:50.0
#
#   2   loss:1.3862   auprc:0.5009   auroc:0.5039   ap@50:0.5024
#   2   loss:1.3862   auprc:0.5009   auroc:0.5030   ap@50:0.5074    time:50.0
#
#   3   loss:1.3861   auprc:0.5002   auroc:0.5056   ap@50:0.5001
#   3   loss:1.3861   auprc:0.5007   auroc:0.5050   ap@50:0.5051    time:50.4
#
#   4   loss:1.3859   auprc:0.5038   auroc:0.5096   ap@50:0.5040
#   4   loss:1.3859   auprc:0.5049   auroc:0.5097   ap@50:0.5096    time:50.8
#
#   5   loss:1.3853   auprc:0.5122   auroc:0.5162   ap@50:0.5128
# ...

# %% [markdown]
# ## 2.3. dTIP(D): DDM-NN

# %%
# %run model/ddm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# cuda
# model training ...
#   0   loss:1.5784   auprc:0.4980   auroc:0.4997   ap@50:0.4984
#   0   loss:1.5784   auprc:0.5012   auroc:0.5015   ap@50:0.5040    time:91.4
#
#   1   loss:1.4922   auprc:0.4958   auroc:0.4999   ap@50:0.4962
#   1   loss:1.4922   auprc:0.4988   auroc:0.5021   ap@50:0.5016    time:91.3
#
#   2   loss:1.4221   auprc:0.4944   auroc:0.5004   ap@50:0.4948
#   2   loss:1.4221   auprc:0.4974   auroc:0.5022   ap@50:0.5002    time:91.1
#
#   3   loss:1.3946   auprc:0.4942   auroc:0.5017   ap@50:0.4954
#   3   loss:1.3946   auprc:0.4964   auroc:0.5023   ap@50:0.5001    time:90.4
#
#   4   loss:1.3940   auprc:0.4964   auroc:0.5019   ap@50:0.4987
#   4   loss:1.3940   auprc:0.4988   auroc:0.5026   ap@50:0.5031    time:89.7
#
#   5   loss:1.3935   auprc:0.4965   auroc:0.5017   ap@50:0.4987
# ...

# %% [markdown]
# ## 2.4. dTIP(P): PPM-GGM-NN

# %%
# %run model/ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# cuda
# model training ...
#   0   loss:1.6282   auprc:0.5000   auroc:0.4990   ap@50:0.4990
#   0   loss:1.6282   auprc:0.5173   auroc:0.5176   ap@50:0.5174    time:47.3
#
#   1   loss:1.4454   auprc:0.5074   auroc:0.5059   ap@50:0.5062
#   1   loss:1.4454   auprc:0.5189   auroc:0.5178   ap@50:0.5190    time:46.3
#
#   2   loss:1.4142   auprc:0.5214   auroc:0.5194   ap@50:0.5194
#   2   loss:1.4142   auprc:0.5348   auroc:0.5324   ap@50:0.5333    time:47.3
#
#   3   loss:1.3904   auprc:0.5393   auroc:0.5394   ap@50:0.5348
#   3   loss:1.3904   auprc:0.5564   auroc:0.5550   ap@50:0.5512    time:45.7
#
#   4   loss:1.3704   auprc:0.5674   auroc:0.5682   ap@50:0.5589
#   4   loss:1.3704   auprc:0.5902   auroc:0.5855   ap@50:0.5780    time:44.9
#
#   5   loss:1.3483   auprc:0.6052   auroc:0.5993   ap@50:0.5945
# ...

# %% [markdown]
# ##2.5. TIP-cat: PPM-GGM-DDM-DF

# %%
# %run model/tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# cuda
# torch.Size([645, 16])
#   0   loss:         auprc:0.4941   auroc:0.4985   ap@50:0.4996
# model training ...
#   1   time:55.08
#   2   time:54.37
#   3   time:55.14
#   4   time:55.48
#   5   time:54.85
#   6   time:55.34
#   7   time:54.92
#   8   time:55.21
#   9   time:55.02
#  10   loss:1.3148   auprc:0.6607   auroc:0.6836   ap@50:0.6646    time:66.8
#  11   time:55.58
#  12   time:55.60
#  13   time:55.31
#  14   time:55.05
#  15   time:54.92
#  16   time:54.63
#  17   time:51.75
#  18   time:51.67
#  19   time:52.42
#  20   loss:1.0103   auprc:0.7849   auroc:0.8389   ap@50:0.7880    time:62.9
#  21   time:52.52
#  22   time:52.02
#  23   time:51.88
#  24   time:52.10
#  25   time:52.62
#  26   time:52.82
#  27   time:51.97
#  28   time:51.70
#  29   time:51.64
#  30   loss:0.8514   auprc:0.8522   auroc:0.8894   ap@50:0.8540    time:62.0
# ...

# %% [markdown]
# ##2.6. TIP-sum: PPM-GGM-DDM-DF

# %%
# %run model/tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# cuda
#   0   loss:         auprc:0.5046   auroc:0.4996   ap@50:0.5099
# model training ...
#   1   time:51.14
#   2   time:51.51
#   3   time:52.14
#   4   time:51.66
#   5   time:51.99
#   6   time:52.74
#   7   time:51.46
#   8   time:51.42
#   9   time:51.97
#  10   loss:1.3677   auprc:0.6139   auroc:0.6080   ap@50:0.6174    time:60.2
#  11   time:53.25
#  12   time:52.65
#  13   time:51.67
#  14   time:52.14
#  15   time:52.78
#  16   time:51.65
#  17   time:51.38
#  18   time:51.88
#  19   time:53.01
#  20   loss:1.0101   auprc:0.8196   auroc:0.8514   ap@50:0.8217    time:61.7
#  21   time:52.06
#  22   time:51.67
#  23   time:51.92
#  24   time:52.46
#  25   time:52.27
#  26   time:52.16
#  27   time:51.39
#  28   time:50.79
#  29   time:51.13
#  30   loss:0.7945   auprc:0.8744   auroc:0.9034   ap@50:0.8759    time:60.3
#  31   time:51.43
# ...

# %% [markdown]
# # **3. Evaluating the model variants**
#
#
# ---
#
#
# # Predicting and storing the Side-effect/Drug-pair probabilities
#
#
# ---
#
#
# ## Total number of drugs = 645
# ## Total number of side-effects = 1,097
# ## Total number of drug-pair combinations = 645*(645-1)/2 = 207,690
# ## Total number of side-effect/drug-pair combinations = 1,097 * 207,690 = 227,835,930
#
#
# ---
#
#
# ## *Processing the 227,835,930 combinations in chunks (through multiple iterations) to prevent resource (RAM/GPU) overflow*

# %% [markdown]
# ## 3.1. DistMult : DF

# %% [markdown]
# ### 3.1.1. Iteration 1: Side effects 0 to 273

# %%
# %run evaluation/eva_df_distmult.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 1
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([0.5000, 0.5000, 0.2721,  ..., 0.0153, 0.1957, 0.0787], device='cuda:0')
# Total number of records processed till now: 56907060
# [[0.5        0.5        0.27211919 ... 0.01531513 0.19567885 0.07867291]]

# %% [markdown]
# ### 3.1.2. Iteration 2: Side effects 274 to 547

# %%
# %run evaluation/eva_df_distmult.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 2
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([0.5000, 0.5000, 0.0260,  ..., 0.0269, 0.1800, 0.0923], device='cuda:0')
# Total number of records processed till now: 113814120
# [[0.5        0.5        0.27211919 ... 0.02694743 0.1800026  0.09225551]]

# %% [markdown]
# ### 3.1.3. Iteration 3: Side effects 548 to 821

# %%
# %run evaluation/eva_df_distmult.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 3
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([0.5000, 0.5000, 0.0289,  ..., 0.0434, 0.2267, 0.2139], device='cuda:0')
# Total number of records processed till now: 170721180

# %% [markdown]
# ### 3.1.4. Iteration 4: Side effects 821 to 1096

# %%
# %run evaluation/eva_df_distmult.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 4
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([0.5000, 0.5000, 0.0560,  ..., 0.0695, 0.2861, 0.1553], device='cuda:0')
# Total number of records processed till now: 227835930

# %% [markdown]
# ## 3.2. RGCN: DDM-DF

# %% [markdown]
# ### 3.2.1. Iteration 1: Side effects 0 to 273

# %%
# %run evaluation/eva_ddm_df_rgcn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 1
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([4.6517e-01, 4.7160e-02, 4.6296e-03,  ..., 5.4373e-14, 1.2552e-31,
#         3.7750e-22], device='cuda:0')
# Total number of records processed till now: 56907060
# [[4.65165049e-01 4.71600331e-02 4.62961476e-03 ... 5.43732573e-14
#   1.25517535e-31 3.77496954e-22]]

# %% [markdown]
# ### 3.2.2. Iteration 2: Side effects 274 to 547

# %%
# %run evaluation/eva_ddm_df_rgcn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 2
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([4.8100e-01, 2.3063e-02, 2.2939e-03,  ..., 1.5744e-11, 8.7016e-26,
#         3.4283e-18], device='cuda:0')
# Total number of records processed till now: 113814120
# [[4.65165049e-01 4.71600331e-02 4.62961476e-03 ... 1.57443086e-11
#   8.70160540e-26 3.42831664e-18]]

# %% [markdown]
# ### 3.2.3. Iteration 3: Side effects 548 to 821

# %%
# %run evaluation/eva_ddm_df_rgcn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 3
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([5.1500e-01, 4.7486e-02, 6.5456e-03,  ..., 1.7265e-12, 5.2381e-28,
#         4.9494e-19], device='cuda:0')
# Total number of records processed till now: 170721180

# %% [markdown]
# ### 3.2.4. Iteration 4: Side effects 822 to 1096

# %%
# %run evaluation/eva_ddm_df_rgcn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 4
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([4.8496e-01, 1.7962e-02, 1.2121e-03,  ..., 6.5889e-12, 2.6178e-26,
#         6.3748e-18], device='cuda:0')
# Total number of records processed till now: 227835930

# %% [markdown]
# ## 3.3. dTIP(D): DDM-NN

# %% [markdown]
# ### 3.3.1. Iteration 1: Side effects 0 to 273

# %%
# %run evaluation/eva_ddm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 1
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([5.0779e-01, 3.7533e-02, 2.7880e-02,  ..., 3.6761e-08, 4.4399e-08,
#         5.9656e-06], device='cuda:0')
# Total number of records processed till now: 56907060
# [[5.07786453e-01 3.75329368e-02 2.78801490e-02 ... 3.67613637e-08
#   4.43987815e-08 5.96562086e-06]]

# %% [markdown]
# ### 3.3.2. Iteration 2: Side effects 274 to 547

# %%
# %run evaluation/eva_ddm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 2
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([5.1515e-01, 2.6564e-02, 1.9765e-02,  ..., 6.1152e-07, 6.5970e-07,
#         3.0688e-05], device='cuda:0')
# Total number of records processed till now: 113814120
# [[5.07786453e-01 3.75329368e-02 2.78801490e-02 ... 6.11521614e-07
#   6.59700163e-07 3.06879992e-05]]

# %% [markdown]
# ### 3.2.3. Iteration 3: Side effects 548 to 821

# %%
# %run evaluation/eva_ddm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 3
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([5.7424e-01, 3.5147e-02, 2.4901e-02,  ..., 1.6870e-06, 1.6309e-06,
#         7.6025e-05], device='cuda:0')
# Total number of records processed till now: 170721180

# %% [markdown]
# ### 3.2.4. Iteration 4: Side effects 822 to 1096

# %%
# %run evaluation/eva_ddm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 4
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# /usr/local/lib/python3.6/dist-packages/torch/utils/checkpoint.py:25: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# storing the results...
# Result of this iteration: tensor([4.6728e-01, 1.8716e-02, 1.2574e-02,  ..., 6.3992e-06, 6.3665e-06,
#         1.6620e-04], device='cuda:0')
# Total number of records processed till now: 227835930

# %% [markdown]
# ## 3.4. dTIP(P): PPM-GGM-NN

# %% [markdown]
# ### 3.4.1. Iteration 1: Side effects 0 to 136

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 1
# loading the trained model...
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 6.5557e-09, 1.5887e-06,
#         3.7705e-03], device='cuda:0')
# Total number of records processed till now: 28453530
# [[5.00000000e-01 5.00000000e-01 5.00000000e-01 ... 6.55573240e-09
#   1.58871580e-06 3.77048459e-03]]

# %% [markdown]
# ### 3.4.2. Iteration 2: Side effects 137 to 273

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 2
# loading the trained model...
# cuda
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 3.2671e-12, 1.1829e-08,
#         4.8866e-04], device='cuda:0')
# Total number of records processed till now: 56907060
# [[5.00000000e-01 5.00000000e-01 5.00000000e-01 ... 3.26708625e-12
#   1.18285870e-08 4.88661346e-04]]

# %% [markdown]
# ### 3.4.3. Iteration 3: Side effects 274 to 410

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 3
# loading the trained model...
# cuda
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 2.0310e-09, 1.2679e-06,
#         3.4327e-03], device='cuda:0')
# Total number of records processed till now: 85360590

# %% [markdown]
# ### 3.4.4. Iteration 4: Side effects 411 to 547

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 4
# loading the trained model...
# cuda
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 1.4825e-09, 7.7491e-07,
#         2.7964e-03], device='cuda:0')
# Total number of records processed till now: 113814120

# %% [markdown]
# ### 3.4.5. Iteration 5: Side effects 548 to 684

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 5
# loading the trained model...
# cuda
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 9.9866e-12, 2.1138e-08,
#         6.2267e-04], device='cuda:0')
# Total number of records processed till now: 142267650

# %% [markdown]
# ### 3.4.6. Iteration 6: Side effects 684 to 821

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 6
# loading the trained model...
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 1.9093e-09, 9.3761e-07,
#         3.0274e-03], device='cuda:0')
# Total number of records processed till now: 170721180

# %% [markdown]
# ### 3.4.7. Iteration 7: Side effects 822 to 958

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 7
# loading the trained model...
# cuda
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 3.6216e-10, 2.5461e-07,
#         1.7586e-03], device='cuda:0')
# Total number of records processed till now: 199174710

# %% [markdown]
# ### 3.4.8. Iteration 8: Side effects 959 to 1096

# %%
# %run evaluation/eva_ppm_ggm_nn.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 8
# loading the trained model...
# cuda
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'src.layers.HierEncoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.0000e-01, 5.0000e-01, 5.0000e-01,  ..., 3.9547e-09, 2.4891e-06,
#         4.5447e-03], device='cuda:0')
# Total number of records processed till now: 227835930

# %% [markdown]
# ## 3.5. TIP-cat: PPM-GGM-DDM-DF

# %% [markdown]
# ### 3.5.1. Iteration 1: Side effects 0 to 136

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 1
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.9293e-01, 5.7959e-02, 2.8854e-03,  ..., 6.6588e-10, 9.1672e-10,
#         7.0925e-10], device='cuda:0')
# Total number of records processed till now: 28453530
# [[5.92929840e-01 5.79587556e-02 2.88540730e-03 ... 6.65881461e-10
#   9.16716703e-10 7.09250381e-10]]

# %% [markdown]
# ### 3.5.2. Iteration 2: Side effects 137 to 273

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 2
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.1370e-01, 2.0767e-02, 8.5345e-04,  ..., 1.0613e-13, 1.9617e-14,
#         9.6405e-14], device='cuda:0')
# Total number of records processed till now: 56907060
# [[5.92929840e-01 5.79587556e-02 2.88540730e-03 ... 1.06130660e-13
#   1.96168138e-14 9.64047838e-14]]

# %% [markdown]
# ### 3.5.3. Iteration 3: Side effects 274 to 410

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 3
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([4.4235e-01, 2.7833e-02, 2.1839e-03,  ..., 1.4286e-12, 2.8434e-12,
#         4.1009e-13], device='cuda:0')
# Total number of records processed till now: 85360590

# %% [markdown]
# ### 3.5.4. Iteration 4: Side effects 411 to 547

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 4
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.4547e-01, 3.2562e-02, 2.9645e-03,  ..., 1.3924e-09, 3.5975e-09,
#         1.2122e-09], device='cuda:0')
# Total number of records processed till now: 113814120

# %% [markdown]
# ### 3.5.5. Iteration 5: Side effects 548 to 684

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 5
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.5086e-01, 3.4380e-02, 2.9960e-03,  ..., 2.3664e-09, 6.3277e-10,
#         1.3455e-09], device='cuda:0')
# Total number of records processed till now: 142267650

# %% [markdown]
# ### 3.5.6. Iteration 6: Side effects 684 to 821

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 6
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.3543e-01, 2.8419e-02, 1.4723e-03,  ..., 2.1656e-09, 4.2967e-09,
#         3.9485e-09], device='cuda:0')
# Total number of records processed till now: 170721180

# %% [markdown]
# ### 3.5.7. Iteration 7: Side effects 822 to 958

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 7
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([4.7045e-01, 2.7558e-02, 1.4294e-03,  ..., 2.5612e-11, 9.7580e-11,
#         4.8290e-11], device='cuda:0')
# Total number of records processed till now: 199174710

# %% [markdown]
# ### 3.5.8. Iteration 8: Side effects 959 to 1096

# %%
# %run evaluation/eva_tip_cat.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 8
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([4.7359e-01, 3.9935e-02, 3.3143e-03,  ..., 1.0600e-08, 2.0966e-08,
#         1.4858e-08], device='cuda:0')
# Total number of records processed till now: 227835930

# %% [markdown]
# ## 3.6. TIP-sum: PPM-GGM-DDM-DF

# %% [markdown]
# ### 3.6.1. Iteration 1: Side effects 0 to 136

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 1
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([6.4199e-01, 3.8872e-02, 1.9716e-03,  ..., 2.8161e-09, 2.7274e-11,
#         2.9492e-10], device='cuda:0')
# Total number of records processed till now: 28453530
# [[6.41985357e-01 3.88722718e-02 1.97160849e-03 ... 2.81613488e-09
#   2.72743304e-11 2.94923419e-10]]

# %% [markdown]
# ### 3.6.2. Iteration 2: Side effects 137 to 273

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 2
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.6759e-01, 2.5647e-02, 1.7261e-03,  ..., 2.1018e-13, 6.5593e-16,
#         3.2969e-14], device='cuda:0')
# Total number of records processed till now: 56907060
# [[6.41985357e-01 3.88722718e-02 1.97160849e-03 ... 2.10177782e-13
#   6.55933579e-16 3.29686094e-14]]

# %% [markdown]
# ### 3.6.3. Iteration 3: Side effects 274 to 410

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 3
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([4.4011e-01, 3.1893e-02, 3.1688e-03,  ..., 1.0414e-11, 1.6852e-13,
#         1.8505e-12], device='cuda:0')
# Total number of records processed till now: 85360590
# [[6.41985357e-01 3.88722718e-02 1.97160849e-03 ... 1.04144141e-11
#   1.68516744e-13 1.85048114e-12]]

# %% [markdown]
# ### 3.6.4. Iteration 4: Side effects 411 to 547

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 4
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([4.9266e-01, 5.1823e-02, 7.7694e-03,  ..., 1.5164e-09, 1.3445e-11,
#         1.3151e-10], device='cuda:0')
# Total number of records processed till now: 113814120
# [[6.41985357e-01 3.88722718e-02 1.97160849e-03 ... 1.51635671e-09
#   1.34447731e-11 1.31512315e-10]]

# %% [markdown]
# ### 3.6.5. Iteration 5: Side effects 548 to 684

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 5
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.7208e-01, 6.1694e-02, 9.2856e-03,  ..., 2.0387e-15, 2.2825e-17,
#         8.7406e-16], device='cuda:0')
# Total number of records processed till now: 142267650

# %% [markdown]
# ### 3.6.6. Iteration 6: Side effects 684 to 821

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 6
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.3195e-01, 2.9816e-02, 2.6481e-03,  ..., 3.2379e-12, 7.3110e-14,
#         7.4787e-13], device='cuda:0')
# Total number of records processed till now: 170721180

# %% [markdown]
# ### 3.6.7. Iteration 7: Side effects 822 to 958

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 7
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.3782e-01, 2.2501e-02, 1.3665e-03,  ..., 8.2551e-13, 8.2520e-15,
#         1.2205e-13], device='cuda:0')
# Total number of records processed till now: 199174710

# %% [markdown]
# ### 3.6.8. Iteration 8: Side effects 959 to 1096

# %%
# %run evaluation/eva_tip_add.py
# Out:
# loading data
# remove  0  isolated drugs:  []
# remove finished
# 1097  polypharmacy side effects
# data has been loaded
# Enter iteration counter to compute next subset of results: 8
# loading the trained model...
# cuda
# evaluating over the entire dataset and generating the results...
# storing the results...
# Result of this iteration: tensor([5.4030e-01, 5.4404e-02, 6.7555e-03,  ..., 1.2790e-10, 5.8099e-12,
#         2.5750e-11], device='cuda:0')
# Total number of records processed till now: 227835930
